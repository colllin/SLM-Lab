# %%
import numpy as np
from realcomp.envs.realcomp_env import Goal
import matplotlib.pyplot as plt

# %%
goals = np.load('../REALCompetitionStartingKit/realcomp/task/goals_dataset.npy', allow_pickle=True)
goals
# Out:
# array([<realcomp.envs.realcomp_env.Goal object at 0x7f1961f10208>,
# ...
#       dtype=object)

# %%
plt.imshow(goals[4].retina / 255)

# %%
goals[0].retina.max()
# Out:
# 254
